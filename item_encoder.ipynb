# %% [markdown]
# ## Item Embeddings
#
# We are going to create an AutoEncoder algorithm in order to have an easy way to find the most similar items in the dataset.

# %%
import pandas as pd
import numpy as np
import category_encoders as ce
import joblib
import tensorflow as tf
import datetime as dt
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import QuantileTransformer
import os

# %%
def num_downcast(df: pd.DataFrame) -> pd.DataFrame:
    """
    Downcasts all numeric columns to lowest int/float type.
    This should help with RAM and speed up certain processes.
    This function will attempt to cast to unsigned ints when
    possible.

    :param df: the DataFrame to be downcasted
    :return: a DataFrame with numeric columns downcasted
    """

    #converts to int, then unsigned int
    for col in df.select_dtypes('number'):
        if df[col].min() < 0:
            df[col] = pd.to_numeric(df[col], downcast='unsigned')
        else:
            df[col] = pd.to_numeric(df[col], downcast='integer')
            
    #downcast to float
    for col in df.select_dtypes(np.float):
        df[col] = pd.to_numeric(df[col], downcast='float')

    return df


def binary_encoding(df: pd.DataFrame,
                    col:str) -> pd.DataFrame:
    """
    Uses library `category_encoders` to encode a nominal categorical feature to a set of columns with 0s and 1s.

    The number of columns needed is:
    feature_cardinality <= 2^n, where n is the number of columns

    Or in other words, it's the math.ceil(log_2(cardinality))


    If a feature has 256 unique values / classes, then log_2(256) = 8, so the data can be encoded in 8 columns

    """
    # use sklearn encoder
    lbe = LabelEncoder()

    # ensure type is str/obj
    X = df[[col]].astype(str).copy()

    y = lbe.fit_transform(np.ravel(X.values))
    be = ce.BinaryEncoder()

    encodings = be.fit_transform(X, y).copy()

    # for some reason, an empty column is always included in the output...
    encodings.drop('{}_0'.format(col), axis=1, inplace=True)
    return encodings

# %%
items = pd.read_json('item_data.jl.gz', lines = True)
items.head()
# Out:
#    item_id                                              title  \
# 0   111260  Casa Sola En Venta Con Gran Patio Solo Pago De...
# 1   871377  Resident Evil Origins Collection Nintendo Swit...
# 2   490232                      Falda De Imitación Piel Negra
# 3  1150706       Powercolor Red Devil Radeon Rx 580 8gb Gddr5
# 4   934912  Laptop Hp Nx6320 Core Duo Con Puerto Db9 Windo...
#
#                         domain_id  product_id       price category_id  \
# 0  MLM-INDIVIDUAL_HOUSES_FOR_SALE         NaN  1150000.00   MLM170527
# 1                 MLM-VIDEO_GAMES  15270800.0     1392.83   MLM151595
# 2                      MLM-SKIRTS         NaN      350.00     MLM7697
# 3              MLM-GRAPHICS_CARDS         NaN     3200.00     MLM9761
# 4                   MLM-NOTEBOOKS         NaN     1599.00     MLM1652
#
#   condition
# 0       new
# 1       new
# 2       new
# 3      used
# 4      used

# %%
##there are some nan values in the domain column
##we need to fix this before creating the embeddings
items.domain_id = np.where(items.domain_id.isna(), 'servicio', items.domain_id)
items_enc = items.copy()

# %% [markdown]
# ## Items Embeddings

# %%
cat_le = LabelEncoder()
for cat_feat in ['domain_id','category_id']:
    old_name = f'original_{cat_feat}'
    items_enc.rename({cat_feat:old_name}, axis=1, inplace=True)
    items_enc[cat_feat] = cat_le.fit_transform(items_enc[old_name])
    
category_to_code_map = dict(zip(items_enc.original_category_id.tolist(), items_enc.category_id.tolist()))
code_to_category_map = {v: k for k, v in category_to_code_map.items()}

domain_to_code_map = dict(zip(items_enc.original_domain_id.tolist(), items_enc.domain_id.tolist()))
code_to_domain_map = {v: k for k, v in domain_to_code_map.items()}

domain_binary_encoding = binary_encoding(items_enc, 'domain_id')
category_binary_encoding = binary_encoding(items_enc, 'category_id')

encoded_df = num_downcast(pd.concat([items_enc, domain_binary_encoding,category_binary_encoding], axis=1))
# Out:
# /usr/local/lib/python3.7/site-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
# /usr/local/lib/python3.7/site-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):

# %%
encoded_df['new'] = np.where(encoded_df['condition'] == 'new', np.int8(1), np.int8(0))

# %% [markdown]
# ## Normalizing price

# %%
gauss_feats = [
    'price',
]
encoded_df['price'] = np.where(encoded_df['price'].isna(), np.int8(0), encoded_df['price'])

transformer_dict = {key: None for key in gauss_feats}
for feat in gauss_feats: 
    new_col = f'{feat}_transformed'
    qt_transform_full = QuantileTransformer(output_distribution='normal')
    encoded_df[new_col] = qt_transform_full.fit_transform(encoded_df[feat].to_numpy().reshape(-1,1))

# %%
encoded_df.reset_index(inplace = True, drop = True)
encoded_df.head().T
# Out:
#                                                                       0  \
# item_id                                                          111260
# title                 Casa Sola En Venta Con Gran Patio Solo Pago De...
# original_domain_id                       MLM-INDIVIDUAL_HOUSES_FOR_SALE
# product_id                                                          NaN
# price                                                          1.15e+06
# original_category_id                                          MLM170527
# condition                                                           new
# domain_id                                                          6105
# category_id                                                        7187
# domain_id_1                                                           0
# domain_id_2                                                           0
# domain_id_3                                                           0
# domain_id_4                                                           0
# domain_id_5                                                           0
# domain_id_6                                                           0
# domain_id_7                                                           0
# domain_id_8                                                           0
# domain_id_9                                                           0
# domain_id_10                                                          0
# domain_id_11                                                          0
# domain_id_12                                                          0
# domain_id_13                                                          1
# category_id_1                                                         0
# category_id_2                                                         0
# category_id_3                                                         0
# category_id_4                                                         0
# category_id_5                                                         0
# category_id_6                                                         0
# category_id_7                                                         0
# category_id_8                                                         0
# category_id_9                                                         0
# category_id_10                                                        0
# category_id_11                                                        0
# category_id_12                                                        0
# category_id_13                                                        0
# category_id_14                                                        1
# new                                                                   1
# price_transformed                                               3.08997
#
#                                                                       1  \
# item_id                                                          871377
# title                 Resident Evil Origins Collection Nintendo Swit...
# original_domain_id                                      MLM-VIDEO_GAMES
# product_id                                                  1.52708e+07
# price                                                           1392.83
# original_category_id                                          MLM151595
# condition                                                           new
# domain_id                                                          7752
# category_id                                                        6749
# domain_id_1                                                           0
# domain_id_2                                                           0
# domain_id_3                                                           0
# domain_id_4                                                           0
# domain_id_5                                                           0
# domain_id_6                                                           0
# domain_id_7                                                           0
# domain_id_8                                                           0
# domain_id_9                                                           0
# domain_id_10                                                          0
# domain_id_11                                                          0
# domain_id_12                                                          1
# domain_id_13                                                          0
# category_id_1                                                         0
# category_id_2                                                         0
# category_id_3                                                         0
# category_id_4                                                         0
# category_id_5                                                         0
# category_id_6                                                         0
# category_id_7                                                         0
# category_id_8                                                         0
# category_id_9                                                         0
# category_id_10                                                        0
# category_id_11                                                        0
# category_id_12                                                        0
# category_id_13                                                        1
# category_id_14                                                        0
# new                                                                   1
# price_transformed                                               1.07434
#
#                                                   2  \
# item_id                                      490232
# title                 Falda De Imitación Piel Negra
# original_domain_id                       MLM-SKIRTS
# product_id                                      NaN
# price                                           350
# original_category_id                        MLM7697
# condition                                       new
# domain_id                                      7273
# category_id                                   11280
# domain_id_1                                       0
# domain_id_2                                       0
# domain_id_3                                       0
# domain_id_4                                       0
# domain_id_5                                       0
# domain_id_6                                       0
# domain_id_7                                       0
# domain_id_8                                       0
# domain_id_9                                       0
# domain_id_10                                      0
# domain_id_11                                      0
# domain_id_12                                      1
# domain_id_13                                      1
# category_id_1                                     0
# category_id_2                                     0
# category_id_3                                     0
# category_id_4                                     0
# category_id_5                                     0
# category_id_6                                     0
# category_id_7                                     0
# category_id_8                                     0
# category_id_9                                     0
# category_id_10                                    0
# category_id_11                                    0
# category_id_12                                    0
# category_id_13                                    1
# category_id_14                                    1
# new                                               1
# price_transformed                          0.432104
#
#                                                                  3  \
# item_id                                                    1150706
# title                 Powercolor Red Devil Radeon Rx 580 8gb Gddr5
# original_domain_id                              MLM-GRAPHICS_CARDS
# product_id                                                     NaN
# price                                                         3200
# original_category_id                                       MLM9761
# condition                                                     used
# domain_id                                                     5890
# category_id                                                  11486
# domain_id_1                                                      0
# domain_id_2                                                      0
# domain_id_3                                                      0
# domain_id_4                                                      0
# domain_id_5                                                      0
# domain_id_6                                                      0
# domain_id_7                                                      0
# domain_id_8                                                      0
# domain_id_9                                                      0
# domain_id_10                                                     0
# domain_id_11                                                     1
# domain_id_12                                                     0
# domain_id_13                                                     0
# category_id_1                                                    0
# category_id_2                                                    0
# category_id_3                                                    0
# category_id_4                                                    0
# category_id_5                                                    0
# category_id_6                                                    0
# category_id_7                                                    0
# category_id_8                                                    0
# category_id_9                                                    0
# category_id_10                                                   0
# category_id_11                                                   0
# category_id_12                                                   1
# category_id_13                                                   0
# category_id_14                                                   0
# new                                                              0
# price_transformed                                          1.37811
#
#                                                                       4
# item_id                                                          934912
# title                 Laptop Hp Nx6320 Core Duo Con Puerto Db9 Windo...
# original_domain_id                                        MLM-NOTEBOOKS
# product_id                                                          NaN
# price                                                              1599
# original_category_id                                            MLM1652
# condition                                                          used
# domain_id                                                          6705
# category_id                                                        7028
# domain_id_1                                                           0
# domain_id_2                                                           0
# domain_id_3                                                           0
# domain_id_4                                                           0
# domain_id_5                                                           0
# domain_id_6                                                           0
# domain_id_7                                                           0
# domain_id_8                                                           0
# domain_id_9                                                           0
# domain_id_10                                                          0
# domain_id_11                                                          1
# domain_id_12                                                          0
# domain_id_13                                                          1
# category_id_1                                                         0
# category_id_2                                                         0
# category_id_3                                                         0
# category_id_4                                                         0
# category_id_5                                                         0
# category_id_6                                                         0
# category_id_7                                                         0
# category_id_8                                                         0
# category_id_9                                                         0
# category_id_10                                                        0
# category_id_11                                                        0
# category_id_12                                                        1
# category_id_13                                                        0
# category_id_14                                                        1
# new                                                                   0
# price_transformed                                               1.13528

# %%
print(encoded_df.shape)
encoded_df.drop_duplicates(subset='item_id', inplace=True)
print(encoded_df.shape)
# Out:
# (2102277, 38)
# (2102277, 38)

# %% [markdown]
# ## Net

# %%
from tensorflow.keras.models import Model
from tensorflow.keras import layers, losses
import tensorflow as tf

# %%
transformed_features = [i for i in encoded_df.columns if '_transformed' in i]
domain_features = [i for i in encoded_df.columns if 'domain_' in i and 'original' not in i]
category_features = [i for i in encoded_df.columns if 'category_' in i and 'original' not in i]

# %%
binary_features_2 = ['new'] + domain_features + category_features
training_features = transformed_features + binary_features_2

# %%
#alt method
latent_dim = 6

class Autoencoder(Model):
    def __init__(self, latent_dim, input_dim):
        super(Autoencoder, self).__init__()
        self.latent_dim = latent_dim
        self.input_dim = input_dim
        self.encoder = tf.keras.Sequential([
            layers.Flatten(),
            layers.GaussianNoise(.01),
            layers.Dense(input_dim, activity_regularizer=tf.keras.regularizers.l1(10e-5)),
            layers.LeakyReLU(),
            layers.GaussianNoise(.01),
            layers.Dense(latent_dim),
            layers.LeakyReLU()
        ])
        self.decoder = tf.keras.Sequential([
          layers.Dense(input_dim),
          layers.LeakyReLU(),
          layers.Dense(input_dim, activation='linear')
        ])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

    
autoencoder = Autoencoder(latent_dim, len(training_features))

# %%
for c in training_features:
    encoded_df[c] = encoded_df[c].astype(float)

# %%
autoencoder_full = Autoencoder(latent_dim, len(training_features)) 
autoencoder_full.compile(optimizer='adam', loss=losses.MeanAbsoluteError(),run_eagerly=True)
autoencoder_full.fit(
    encoded_df[training_features].to_numpy(), encoded_df[training_features].to_numpy(),
                epochs=30,
                shuffle=True,
                batch_size=256,
                    )
# Out:
# Epoch 1/30
# 8213/8213 [==============================] - 98s 12ms/step - loss: 22.7774
# Epoch 2/30
# 8213/8213 [==============================] - 95s 12ms/step - loss: 2.5024
# Epoch 3/30
# 8213/8213 [==============================] - 103s 13ms/step - loss: 2.1266
# Epoch 4/30
# 8213/8213 [==============================] - 103s 13ms/step - loss: 1.8813
# Epoch 5/30
# 8213/8213 [==============================] - 97s 12ms/step - loss: 1.7116
# Epoch 6/30
# 8213/8213 [==============================] - 97s 12ms/step - loss: 1.6105
# Epoch 7/30
# 8213/8213 [==============================] - 96s 12ms/step - loss: 1.4908
# Epoch 8/30
# 8213/8213 [==============================] - 97s 12ms/step - loss: 1.3806
# Epoch 9/30
# 8213/8213 [==============================] - 92s 11ms/step - loss: 1.3216
# Epoch 10/30
# 8213/8213 [==============================] - 92s 11ms/step - loss: 1.2805
# Epoch 11/30
# 8213/8213 [==============================] - 92s 11ms/step - loss: 1.2214
# Epoch 12/30
# 8213/8213 [==============================] - 95s 12ms/step - loss: 1.1725
# Epoch 13/30
# 8213/8213 [==============================] - 92s 11ms/step - loss: 1.1475
# Epoch 14/30
# 8213/8213 [==============================] - 90s 11ms/step - loss: 1.1103
# Epoch 15/30
# 8213/8213 [==============================] - 88s 11ms/step - loss: 1.0851
# Epoch 16/30
# 8213/8213 [==============================] - 88s 11ms/step - loss: 1.0667
# Epoch 17/30
# 8213/8213 [==============================] - 90s 11ms/step - loss: 1.0641
# Epoch 18/30
# 8213/8213 [==============================] - 87s 11ms/step - loss: 1.0258
# Epoch 19/30
# 8213/8213 [==============================] - 87s 11ms/step - loss: 0.9942
# Epoch 20/30
# 8213/8213 [==============================] - 88s 11ms/step - loss: 0.9971
# Epoch 21/30
# 8213/8213 [==============================] - 88s 11ms/step - loss: 0.9804
# Epoch 22/30
# 8213/8213 [==============================] - 87s 11ms/step - loss: 0.9703
# Epoch 23/30
# 8213/8213 [==============================] - 88s 11ms/step - loss: 0.9587
# Epoch 24/30
# 8213/8213 [==============================] - 87s 11ms/step - loss: 0.9604
# Epoch 25/30
# 8213/8213 [==============================] - 87s 11ms/step - loss: 0.9540
# Epoch 26/30
# 8213/8213 [==============================] - 87s 11ms/step - loss: 0.9593
# Epoch 27/30
# 8213/8213 [==============================] - 87s 11ms/step - loss: 0.9434
# Epoch 28/30
# 8213/8213 [==============================] - 88s 11ms/step - loss: 0.9373
# Epoch 29/30
# 8213/8213 [==============================] - 87s 11ms/step - loss: 0.9374
# Epoch 30/30
# 8213/8213 [==============================] - 88s 11ms/step - loss: 0.9285

# %%
p = autoencoder_full.encoder(encoded_df[training_features].to_numpy().astype(np.float32)).numpy()

# %%
items = pd.DataFrame(p, index = encoded_df.item_id, columns = [str(x) for x in range(6)])
items.to_parquet('items_embeddings.parquet')
